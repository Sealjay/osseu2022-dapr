# %% [markdown]
# # DAPR - Usage in the real world

# %% [markdown]
# #### Agenda
# - Introductions - and how you can follow along
#     - What is DAPR?!?

# %% [markdown]
# - Architecture of DAPR
#     - Example of DAPR in use

# %% [markdown]
# - Let's get some demos working!
#      - And hope Jupyter works for everyone.
#      - You'll be able to run this Jupyter notebook

# %% [markdown]
# - Wrap-up
#      - And any questions you have, that we haven't covered

# %% [markdown]
# ## You will require Docker, and the DAPR CLI.
# If you go on https://github.com/Sealjay/osseu2022-dapr you can follow along.
#
# I assume you know how to install Docker... but

# %% [markdown]
# ### Installing DAPR CLI
# Whilst I'm talking, you'll need to install the DAPR CLI.
# > Source: https://docs.dapr.io/getting-started/install-dapr-cli/

# %% [markdown]
# #### Linux
# ##### Install from Terminal
# Install the latest Linux Dapr CLI to /usr/local/bin:

# %%
# !wget -q https://raw.githubusercontent.com/dapr/cli/master/install/install.sh -O - | /bin/bash

# %% [markdown]
# #####  Install without sudo
# If you do not have access to the sudo command or your username is not in the sudoers file, you can install Dapr to an alternate directory via the DAPR_INSTALL_DIR environment variable. This directory must already exist and be accessible by the current user.

# %%
# %%bash
# wget -q https://raw.githubusercontent.com/dapr/cli/master/install/install.sh -O - | DAPR_INSTALL_DIR="$HOME/dapr" /bin/bash

# %% [markdown]
# #### Windows

# %%
# !powershell -Command "iwr -useb https://raw.githubusercontent.com/dapr/cli/master/install/install.ps1 | iex"

# %% [markdown]
# #### Mac Example
# Install via HomeBrew

# %%
# %%bash
# brew install dapr/tap/dapr-cli

# %% [markdown]
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# # Background to DAPR
# ![image.png](attachment:image.png)

# %% [markdown]
# # Typical Microservices Application
# ![image.png](attachment:image.png)

# %% [markdown]
# # Developer problems
# ![image.png](attachment:image.png)

# %% [markdown]
# # So... DAPR!
# ![image.png](attachment:image.png)

# %% [markdown]
# # DAPR - a CNCF project
# ![image.png](attachment:image.png)

# %% [markdown]
# # Architecture of DAPR
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # DAPR APIs
# ![image.png](attachment:image.png)

# %% [markdown]
# # DAPR Sidecar Model
# ![image.png](attachment:image.png)

# %% [markdown]
# # Capabilities not tight coupling
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # DAPR Components
# ![image.png](attachment:image.png)

# %% [markdown]
# # Let's get some demos working!

# %% [markdown]
# # Wrap-up

# %%
# %%bash
# ls
